# %% [markdown]
# ## TOC:
# * [EDA](#Loading)
# * [Continous Feature selection](#Selecting-continous)
# * [Cross-Validation dataset](#cross-validation)
# * [Logistic Regression tuning](#Logistic)
# * [SVM tuning](#SVM)
# * [Random Forest tuning](#RF)
# * [Gradient Boost tuning](#GB)
# * [Extra Trees tuning](#EXT)
# * [Summary](#Summary)
#
# *Week 5 Assignment*
#
# **EDA and Training Categorization Models**
# ***Ryan Amundson***
#
# In this notebook, we are starting some explority data anaylsis along with training a logistic regression model. We are also then training a random forest and finally, trying a XGBboost categorizion, which is a boosting algorithm that can also handle categorical data. For all of the models, I'm attempting to search through some of the hyperparemters with a grid search.
#
# In the EDA, we also have a lot of features that we can use, so I'm starting with the top 25 based on Chi squared testing. From those I removed the highly correlated features based on the correlation matrix and use the rest to create a test/train set for cross validation.
#
# For training a model and fitting, I'm doning a grid search for a set of prameters for each model to try to optimize the model fit for each model. There is no Kaggle competition for this data, sadly, so I can only compare AUC and ROC curves for the categorisation data.

# %%
# Imports
from scipy import stats
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.tree import DecisionTreeRegressor
from yellowbrick.features import FeatureImportances
from sklearn.ensemble import RandomForestRegressor
from yellowbrick.features import Rank1D, Rank2D
from sklearn import metrics 
import seaborn as sns

from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler

from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score

from imblearn.over_sampling import SMOTE


# %matplotlib inline

# %% [markdown]
# ## EDA <a class="anchor" id="Loading"></a>

# %%
# Set some options to see more columns
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)


bankDf = pd.read_csv('bankrupt/data.csv')

print("There are {} missing rows in the data".format(sum(bankDf.isna().sum())))

bankCleanDf = bankDf.dropna()

print("There are {} features in the data".format(len(bankCleanDf.columns)))

bankCleanDf.columns

# Clean up the coulm names
bankCleanDf.columns = bankCleanDf.columns.str.strip()

# Find anything that looks like a boolean flag
binaryCats = [col for col in bankCleanDf.columns if len(bankCleanDf[col].unique()) == 2]

print("There are {} binary categories in the data".format(len(binaryCats)))
print("They are {}".format(binaryCats))

print("Types are either {}".format(set(list(bankCleanDf.dtypes))))

# It looks like there is only one boolean flag and then the category we would like to predict, "bankrupt?", all other
# types are floats

columns = set(list(bankCleanDf.columns)) - set(['Bankrupt?'])
# Out:
# There are 0 missing rows in the data
# There are 96 features in the data
# There are 2 binary categories in the data
# They are ['Bankrupt?', 'Liability-Assets Flag']
# Types are either {dtype('int64'), dtype('float64')}

# %%
bankCleanDf.describe()
# Out:
#          Bankrupt?  ROA(C) before interest and depreciation before interest  ROA(A) before interest and % after tax  ROA(B) before interest and depreciation after tax  Operating Gross Margin  Realized Sales Gross Margin  Operating Profit Rate  Pre-tax net Interest Rate  After-tax net Interest Rate  Non-industry income and expenditure/revenue  Continuous interest rate (after tax)  Operating Expense Rate  Research and development expense rate  Cash flow rate  Interest-bearing debt interest rate  Tax rate (A)  Net Value Per Share (B)  Net Value Per Share (A)  Net Value Per Share (C)  Persistent EPS in the Last Four Seasons  Cash Flow Per Share  Revenue Per Share (Yuan ¥)  Operating Profit Per Share (Yuan ¥)  Per Share Net profit before tax (Yuan ¥)  Realized Sales Gross Profit Growth Rate  Operating Profit Growth Rate  After-tax Net Profit Growth Rate  Regular Net Profit Growth Rate  Continuous Net Profit Growth Rate  Total Asset Growth Rate  Net Value Growth Rate  \
splitColumns = np.array_split(np.asarray(list(columns)), 10);

fig, axs = plt.subplots(5, 2, figsize=(10, 20))

i = 0
for c1, c2 in zip(splitColumns[::2], splitColumns[1::2]):
    bankScaledDf[list(c1)].plot(kind='box', title='Boxplot of continous variables in dataset', showmeans=True, ax=axs[i][0])
    bankScaledDf[list(c2)].plot(kind='box', title='Boxplot of continous variables in dataset', showmeans=True, ax=axs[i][1])
    for t in axs[i][0].get_xticklabels():
        t.set_rotation(45)
    for t in axs[i][1].get_xticklabels():
        t.set_rotation(45)
    i = i + 1

fig.tight_layout()
plt.show()
# Out:
# /var/folders/cj/b27zth7d1gn3ktvbyzc3h69c0000gn/T/ipykernel_29333/3704722446.py:7: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   bankScaledDf = scaler.fit_transform(bankCleanDf[columns].to_numpy())

# %%
bankScaledDf["Current Ratio"].unique
# Out:
# <bound method Series.unique of 0       8.214412e-13
# 1       2.187711e-12
# 2       4.197292e-12
# 3       1.525112e-12
# 4       2.189980e-12
#             ...
# 6814    3.800187e-12
# 6815    3.367001e-12
# 6816    1.397222e-11
# 6817    4.648177e-12
# 6818    1.867213e-11
# Name: Current Ratio, Length: 6819, dtype: float64>

# %%
# Let's take the chi squared top 50 features for feature selection 

selector = SelectKBest(chi2, k=75)
bankScaleTop25df = selector.fit_transform(bankScaledDf[columns], bankCleanDf['Bankrupt?'])

top25Cols = list(bankScaledDf[columns].columns.values[selector.get_support()])

top25Cols
# Out:
# /var/folders/cj/b27zth7d1gn3ktvbyzc3h69c0000gn/T/ipykernel_29333/2114840222.py:4: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   bankScaleTop25df = selector.fit_transform(bankScaledDf[columns], bankCleanDf['Bankrupt?'])
# /var/folders/cj/b27zth7d1gn3ktvbyzc3h69c0000gn/T/ipykernel_29333/2114840222.py:6: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   top25Cols = list(bankScaledDf[columns].columns.values[selector.get_support()])
# ['Realized Sales Gross Margin',
#  'Current Asset Turnover Rate',
#  'Cash Reinvestment %',
#  'Total Asset Turnover',
#  'Current Liabilities/Equity',
#  'Per Share Net profit before tax (Yuan ¥)',
#  'Current Liability to Assets',
#  'Allocation rate per person',
#  'Net Value Per Share (A)',
#  'Working Capital to Total Assets',
#  'Equity to Liability',
#  'Fixed Assets to Assets',
#  'Net Value Growth Rate',
#  'Net Income to Total Assets',
#  'Operating Expense Rate',
#  'Contingent liabilities/Net worth',
#  'Net worth/Assets',
#  'Current Liability to Liability',
#  'Current Ratio',
#  'Degree of Financial Leverage (DFL)',
#  'Persistent EPS in the Last Four Seasons',
#  'Total debt/Total net worth',
#  'Current Liability to Equity',
#  'Operating Funds to Liability',
#  'Gross Profit to Sales',
#  'Liability to Equity',
#  'Equity to Long-term Liability',
#  'Inventory and accounts receivable/Net value',
#  'Long-term fund suitability ratio (A)',
#  'Cash/Current Liability',
#  'Average Collection Days',
#  'Fixed Assets Turnover Frequency',
#  'Cash Turnover Rate',
#  'Total assets to GNP price',
#  'Operating Profit Per Share (Yuan ¥)',
#  'Cash Flow to Liability',
#  'CFO to Assets',
#  'Operating profit per person',
#  "Net Income to Stockholder's Equity",
#  'Cash Flow to Total Assets',
#  'Quick Assets/Total Assets',
#  'Total expense/Assets',
#  'Tax rate (A)',
#  'Operating profit/Paid-in capital',
#  'Net profit before tax/Paid-in capital',
#  'Quick Assets/Current Liability',
#  'Current Liabilities/Liability',
#  'Debt ratio %',
#  'Cash Flow Per Share',
#  'Net Value Per Share (B)',
#  'Accounts Receivable Turnover',
#  'Revenue Per Share (Yuan ¥)',
#  'Retained Earnings to Total Assets',
#  'Cash Flow to Equity',
#  'Cash flow rate',
#  'Revenue per person',
#  'ROA(B) before interest and depreciation after tax',
#  'Borrowing dependency',
#  'Working Capital/Equity',
#  'Quick Asset Turnover Rate',
#  'Cash/Total Assets',
#  'Total income/Total expense',
#  'Net Value Per Share (C)',
#  'Quick Ratio',
#  'Net Worth Turnover Rate (times)',
#  'Liability-Assets Flag',
#  'Current Liability to Current Assets',
#  'Current Assets/Total Assets',
#  'Interest-bearing debt interest rate',
#  'ROA(A) before interest and % after tax',
#  'Inventory Turnover Rate (times)',
#  'ROA(C) before interest and depreciation before interest',
#  'Total Asset Growth Rate',
#  'Operating Gross Margin',
#  'Research and development expense rate']

# %%
# Lets also do a correlation matrix of the top 25 continous variblss to get an idea of how correlated they are
corrMat = bankScaledDf[top25Cols].corr().abs()

fig, ax = plt.subplots(figsize=(13, 9))
sns.set(font_scale = 1)
sns.heatmap(corrMat, annot=True, cmap="Reds")
# Out:
# <AxesSubplot:>

# %%
# From the correlation matrix, we can see there are few highly correlated features, at around 99%, so let's remove 
# some of those ad then make teat/train set using the rest. 

upper_tri = corrMat.where(np.triu(np.ones(corrMat.shape),k=1).astype(np.bool))

corDrop = [column for column in upper_tri.columns if any(upper_tri[column] > 0.95)]

topCats = set(top25Cols) - set(corDrop)

topCats
# Out:
# /var/folders/cj/b27zth7d1gn3ktvbyzc3h69c0000gn/T/ipykernel_29333/3973699510.py:4: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   upper_tri = corrMat.where(np.triu(np.ones(corrMat.shape),k=1).astype(np.bool))
# {'Accounts Receivable Turnover',
#  'Allocation rate per person',
#  'Average Collection Days',
#  'CFO to Assets',
#  'Cash Flow Per Share',
#  'Cash Flow to Equity',
#  'Cash Flow to Liability',
#  'Cash Flow to Total Assets',
#  'Cash Reinvestment %',
#  'Cash Turnover Rate',
#  'Cash flow rate',
#  'Cash/Current Liability',
#  'Cash/Total Assets',
#  'Contingent liabilities/Net worth',
#  'Current Asset Turnover Rate',
#  'Current Assets/Total Assets',
#  'Current Liabilities/Equity',
#  'Current Liability to Assets',
#  'Current Liability to Current Assets',
#  'Current Liability to Liability',
#  'Current Ratio',
#  'Degree of Financial Leverage (DFL)',
#  'Equity to Liability',
#  'Equity to Long-term Liability',
#  'Fixed Assets Turnover Frequency',
#  'Fixed Assets to Assets',
#  'Interest-bearing debt interest rate',
#  'Inventory Turnover Rate (times)',
#  'Inventory and accounts receivable/Net value',
#  'Liability-Assets Flag',
#  'Long-term fund suitability ratio (A)',
#  "Net Income to Stockholder's Equity",
#  'Net Income to Total Assets',
#  'Net Value Growth Rate',
#  'Net Value Per Share (A)',
#  'Net Worth Turnover Rate (times)',
#  'Net worth/Assets',
#  'Operating Expense Rate',
#  'Operating Funds to Liability',
#  'Operating Profit Per Share (Yuan ¥)',
#  'Operating profit per person',
#  'Per Share Net profit before tax (Yuan ¥)',
#  'Quick Asset Turnover Rate',
#  'Quick Assets/Current Liability',
#  'Quick Assets/Total Assets',
#  'Quick Ratio',
#  'ROA(B) before interest and depreciation after tax',
#  'Realized Sales Gross Margin',
#  'Research and development expense rate',
#  'Retained Earnings to Total Assets',
#  'Revenue Per Share (Yuan ¥)',
#  'Revenue per person',
#  'Tax rate (A)',
#  'Total Asset Growth Rate',
#  'Total Asset Turnover',
#  'Total assets to GNP price',
#  'Total debt/Total net worth',
#  'Total expense/Assets',
#  'Total income/Total expense',
#  'Working Capital to Total Assets',
#  'Working Capital/Equity'}

# %% [markdown]
# ## Cross-validation dataset creation <a class="anchor" id="cross-validation"></a>

# %%
# Now let's create a test/traing set with those features

X, X_test, y, y_test = train_test_split(bankCleanDf[topCats].copy(), 
                                        bankCleanDf['Bankrupt?'], 
                                        test_size=0.2, 
                                        random_state=42)
# Out:
# /var/folders/cj/b27zth7d1gn3ktvbyzc3h69c0000gn/T/ipykernel_29333/4138092390.py:3: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   X, X_test, y, y_test = train_test_split(bankCleanDf[topCats].copy(),

# %%
sns.countplot(x=y)
# Out:
# <AxesSubplot:xlabel='Bankrupt?', ylabel='count'>

# %%
#Oversampling the data
smote = SMOTE(random_state=101)
X, y = smote.fit_resample(X, y)

sns.countplot(x=y)
# Out:
# <AxesSubplot:xlabel='Bankrupt?', ylabel='count'>

# %%
print("Make sure the columns are the same")

assert(len( X.columns) == len(X_test.columns))
# Out:
# Make sure the columns are the same

# %% [markdown]
# ## Logistic Regression Tuning <a class="anchor" id="Logistic"></a>

# %%
# Becaouse of the massive right skew, lets apply a log transform to normalize the loss data more, and 
# then run a linear model logistic regression on the data to get a baseline

from sklearn.linear_model import LogisticRegression
from sklearn.compose import TransformedTargetRegressor
from sklearn.pipeline import Pipeline
from sklearn.experimental import enable_halving_search_cv
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import confusion_matrix

from sklearn.metrics import precision_recall_curve
from sklearn.metrics import PrecisionRecallDisplay
from sklearn.metrics import roc_curve
from sklearn.metrics import auc
from sklearn.metrics import RocCurveDisplay

# Some incompatible parameters produce a ton of warnings but then are skipped, lets ignore those for now
import warnings
warnings.filterwarnings("ignore")

# Let's try a series of alphas for parameter tuning
# Along with attempting some parametric pareters and different types of penalties for regularisation
grid = {}
grid['linear_regression__C'] = np.linspace(0.1, 1, num=7)
grid['linear_regression__l1_ratio'] = np.linspace(0.1, 0.9, num=9)
grid['linear_regression__penalty'] = ['elasticnet']
grid['linear_regression__solver'] = ['saga']

linear_regression = LogisticRegression(max_iter=1000)
pipeline = Pipeline([("scaler", MinMaxScaler()),
                    ("linear_regression", linear_regression)])

gscv = GridSearchCV(
                    pipeline, 
                    grid, 
                    scoring='f1', 
                    cv=3,
                    error_score=0.0,
                    n_jobs=4)

l_grid_result = gscv.fit(X, y)
    
l_best_params = l_grid_result.best_params_

print("Best alpha parameter: {}".format(l_best_params))

# prepare the model with target scaling
best_c = l_best_params['linear_regression__C']
best_l1 = l_best_params['linear_regression__l1_ratio']
best_penalty = l_best_params['linear_regression__penalty']
linear_regression =  LogisticRegression(penalty=best_penalty, l1_ratio=best_l1, C=best_c, solver='saga', max_iter=1000)

pipeline = Pipeline([("scaler", MinMaxScaler()),
                    ("linear_regression", linear_regression)])


pipeline.fit(X, y)
y_pred = pipeline.predict(X_test)

fig, axs = plt.subplots(3, 1, figsize=(10, 15))

conMatrix = confusion_matrix(y_test, y_pred)

ax = sns.heatmap(conMatrix, annot=True, fmt=".0f", cmap='Blues', ax=axs[0])

ax.set_title('Seaborn Confusion Matrix\n');
ax.set_xlabel('Predicted Values')
ax.set_ylabel('Actual Values');

## Ticket labels - List must be in alphabetical order
ax.xaxis.set_ticklabels(['False','True'])
ax.yaxis.set_ticklabels(['False','True'])

fpr, tpr, _ = roc_curve(y_test, y_pred, drop_intermediate=False)
roc_display = RocCurveDisplay(fpr=fpr, tpr=tpr, roc_auc=auc(fpr, tpr))

prec, recall, _ = precision_recall_curve(y_test, y_pred)
pr_display = PrecisionRecallDisplay(precision=prec, recall=recall)

roc_display.plot(ax=axs[1])
pr_display.plot(ax=axs[2])

## Display the visualization of the Confusion Matrix.
plt.show()
# Out:
# Best alpha parameter: {'linear_regression__C': 1.0, 'linear_regression__l1_ratio': 0.9, 'linear_regression__penalty': 'elasticnet', 'linear_regression__solver': 'saga'}

# %%
# Let's also print the accuracy and recall scores
print("Precision score: {:.2f}".format(metrics.precision_score(y_test, y_pred)))
print("Recall score: {:.2f}".format(metrics.recall_score(y_test, y_pred)))
print("Accuracy score: {:.2f}".format(metrics.accuracy_score(y_test, y_pred)))
print("F1 score: {:.2f}".format(metrics.f1_score(y_test, y_pred)))
# Out:
# Precision score: 0.20
# Recall score: 0.80
# Accuracy score: 0.87
# F1 score: 0.32

# %% [markdown]
# ## SVM Tuning <a class="anchor" id="SVM"></a>

# %%
# Next train a SVM model
from sklearn import svm

# Some incompatible parameters produce a ton of warnings but then are skipped, lets ignore those for now
import warnings
warnings.filterwarnings("ignore")


grid = {}
grid['linear_regression__C'] = np.linspace(1, 10, num=9)
grid['linear_regression__degree'] = [2,3,5,9,15]
grid['linear_regression__kernel'] = ['poly', 'rbf', 'sigmoid']

linear_regression = svm.SVC(max_iter=-1)
pipeline = Pipeline([("scaler", MinMaxScaler()),
                    ("linear_regression", linear_regression)])

gscv = GridSearchCV(
                    pipeline, 
                    grid, 
                    scoring='f1', 
                    cv=3,
                    error_score=0.0,
                    n_jobs=4)

l_grid_result = gscv.fit(X, y)
    
l_best_params = l_grid_result.best_params_

print("Best parameters: {}".format(l_best_params))

# prepare the model with target scaling
best_degree = l_best_params['linear_regression__degree']
best_c = l_best_params['linear_regression__C']
best_kernel = l_best_params['linear_regression__kernel']
linear_regression =  svm.SVC(kernel=best_kernel, C=best_c,
                             degree=best_degree, max_iter=-1)

pipeline = Pipeline([("scaler", MinMaxScaler()),
                    ("linear_regression", linear_regression)])


pipeline.fit(X, y)
y_pred = pipeline.predict(X_test)

fig, axs = plt.subplots(3, 1, figsize=(10, 15))

conMatrix = confusion_matrix(y_test, y_pred)

ax = sns.heatmap(conMatrix, annot=True, fmt=".0f", cmap='Blues', ax=axs[0])

ax.set_title('Seaborn Confusion Matrix\n');
ax.set_xlabel('Predicted Values')
ax.set_ylabel('Actual Values');

## Ticket labels - List must be in alphabetical order
ax.xaxis.set_ticklabels(['False','True'])
ax.yaxis.set_ticklabels(['False','True'])

fpr, tpr, _ = roc_curve(y_test, y_pred, drop_intermediate=False)
roc_display = RocCurveDisplay(fpr=fpr, tpr=tpr, roc_auc=auc(fpr, tpr))

prec, recall, _ = precision_recall_curve(y_test, y_pred)
pr_display = PrecisionRecallDisplay(precision=prec, recall=recall)

roc_display.plot(ax=axs[1])
pr_display.plot(ax=axs[2])

## Display the visualization of the Confusion Matrix.
plt.show()
# Out:
# Best parameters: {'linear_regression__C': 2.125, 'linear_regression__degree': 9, 'linear_regression__kernel': 'poly'}

# %%
# Let's also print the accuracy and recall scores
print("Precision score: {:.2f}".format(metrics.precision_score(y_test, y_pred)))
print("Recall score: {:.2f}".format(metrics.recall_score(y_test, y_pred)))
print("Accuracy score: {:.2f}".format(metrics.accuracy_score(y_test, y_pred)))
print("F1 score: {:.2f}".format(metrics.f1_score(y_test, y_pred)))
# Out:
# Precision score: 0.31
# Recall score: 0.45
# Accuracy score: 0.94
# F1 score: 0.37

# %% [markdown]
# ## Naive Bayes Tuning <a class="anchor" id="NB"></a>

# %%
# Train a Nsive Bayes model 
from sklearn.naive_bayes import MultinomialNB

# Some incompatible parameters produce a ton of warnings but then are skipped, lets ignore those for now
import warnings
warnings.filterwarnings("ignore")


grid = {}
grid['linear_regression__alpha'] = np.linspace(0.00001, 2, num=15)

linear_regression = MultinomialNB()
pipeline = Pipeline([("scaler", MinMaxScaler()),
                    ("linear_regression", linear_regression)])

gscv = GridSearchCV(
                    pipeline, 
                    grid, 
                    scoring='f1', 
                    cv=3,
                    error_score=0.0,
                    n_jobs=4)

l_grid_result = gscv.fit(X, y)
    
l_best_params = l_grid_result.best_params_

print("Best parameters: {}".format(l_best_params))

# prepare the model with target scaling
best_alpha = l_best_params['linear_regression__alpha']
linear_regression =  MultinomialNB(alpha=best_alpha)

pipeline = Pipeline([("scaler", MinMaxScaler()),
                    ("linear_regression", linear_regression)])


pipeline.fit(X, y)
y_pred = pipeline.predict(X_test)

fig, axs = plt.subplots(3, 1, figsize=(10, 15))

conMatrix = confusion_matrix(y_test, y_pred)

ax = sns.heatmap(conMatrix, annot=True, fmt=".0f", cmap='Blues', ax=axs[0])

ax.set_title('Seaborn Confusion Matrix\n');
ax.set_xlabel('Predicted Values')
ax.set_ylabel('Actual Values');

## Ticket labels - List must be in alphabetical order
ax.xaxis.set_ticklabels(['False','True'])
ax.yaxis.set_ticklabels(['False','True'])

fpr, tpr, _ = roc_curve(y_test, y_pred, drop_intermediate=False)
roc_display = RocCurveDisplay(fpr=fpr, tpr=tpr, roc_auc=auc(fpr, tpr))

prec, recall, _ = precision_recall_curve(y_test, y_pred)
pr_display = PrecisionRecallDisplay(precision=prec, recall=recall)

roc_display.plot(ax=axs[1])
pr_display.plot(ax=axs[2])

## Display the visualization of the Confusion Matrix.
plt.show()
# Out:
# Best parameters: {'linear_regression__alpha': 1e-05}

# %%
# Let's also print the accuracy and recall scores
print("Precision score: {:.2f}".format(metrics.precision_score(y_test, y_pred)))
print("Recall score: {:.2f}".format(metrics.recall_score(y_test, y_pred)))
print("Accuracy score: {:.2f}".format(metrics.accuracy_score(y_test, y_pred)))
print("F1 score: {:.2f}".format(metrics.f1_score(y_test, y_pred)))
# Out:
# Precision score: 0.12
# Recall score: 0.78
# Accuracy score: 0.77
# F1 score: 0.21

# %% [markdown]
# ## Random Forest Tuning <a class="anchor" id="RF"></a>

# %%
# Train a Random forest
from sklearn.ensemble import RandomForestClassifier

grid = {}
grid['regressor__max_depth'] = [12, 15, 20, 25]
grid['regressor__criterion'] = ["gini", "entropy"]
grid['regressor__n_estimators'] = [300, 400, 500]
#grid['regressor__min_impurity_decrease'] = np.linspace(0.00000, 1, num=5)
grid['regressor__max_features'] = ["sqrt", "log2", len(X.columns)] 

regressor = RandomForestClassifier()
pipeline = Pipeline([("scaler", MinMaxScaler()),
                    ("regressor", regressor)])

gscv = GridSearchCV(
                    pipeline, 
                    grid, 
                    scoring='f1', 
                    cv=3,
                    error_score=0.0,
                    n_jobs=4)

#l_grid_result = gscv.fit(X, y)
    
l_best_params = {'regressor__criterion': 'gini', 'regressor__max_depth': 25, 'regressor__max_features': 'log2', 'regressor__n_estimators': 300} #l_grid_result.best_params_

print("Best parameters: {}".format(l_best_params))

# prepare the model with target scaling
best_depth = l_best_params['regressor__max_depth']
best_n_estimators = l_best_params['regressor__n_estimators']
best_criterion = l_best_params['regressor__criterion']
best_max_features = l_best_params['regressor__max_features']
best_min_impurity_decrease = 0.0 #l_best_params['regressor__min_impurity_decrease']

linear_regression =  RandomForestClassifier(max_depth=best_depth,
                                            n_estimators=best_n_estimators,
                                            criterion=best_criterion,
                                            max_features=best_max_features,
                                            min_impurity_decrease=best_min_impurity_decrease)

pipeline = Pipeline([("scaler", MinMaxScaler()),
                    ("regressor", linear_regression)])


pipeline.fit(X, y)
y_pred = pipeline.predict(X_test)

fig, axs = plt.subplots(3, 1, figsize=(10, 15))

conMatrix = confusion_matrix(y_test, y_pred)

ax = sns.heatmap(conMatrix, annot=True, fmt=".0f", cmap='Blues', ax=axs[0])

ax.set_title('Seaborn Confusion Matrix\n');
ax.set_xlabel('Predicted Values')
ax.set_ylabel('Actual Values');

## Ticket labels - List must be in alphabetical order
ax.xaxis.set_ticklabels(['False','True'])
ax.yaxis.set_ticklabels(['False','True'])

fpr, tpr, _ = roc_curve(y_test, y_pred, drop_intermediate=False)
roc_display = RocCurveDisplay(fpr=fpr, tpr=tpr, roc_auc=auc(fpr, tpr))

prec, recall, _ = precision_recall_curve(y_test, y_pred)
pr_display = PrecisionRecallDisplay(precision=prec, recall=recall)

roc_display.plot(ax=axs[1])
pr_display.plot(ax=axs[2])

## Display the visualization of the Confusion Matrix.
plt.show()
# Out:
# Best parameters: {'regressor__criterion': 'gini', 'regressor__max_depth': 25, 'regressor__max_features': 'log2', 'regressor__n_estimators': 300}

# %%
# Let's also print the accuracy and recall scores
print("Precision score: {:.2f}".format(metrics.precision_score(y_test, y_pred)))
print("Recall score: {:.2f}".format(metrics.recall_score(y_test, y_pred)))
print("Accuracy score: {:.2f}".format(metrics.accuracy_score(y_test, y_pred)))
print("F1 score: {:.2f}".format(metrics.f1_score(y_test, y_pred)))
# Out:
# Precision score: 0.35
# Recall score: 0.65
# Accuracy score: 0.94
# F1 score: 0.46

# %% [markdown]
# ## Gradient Boost Tuning <a class="anchor" id="RF"></a>

# %%
import xgboost as xgb
from sklearn.experimental import enable_halving_search_cv 
from sklearn.model_selection import HalvingGridSearchCV, RandomizedSearchCV

# Some incompatible parameters produce a ton of warnings but then are skipped, lets ignore those for now
import warnings
warnings.filterwarnings("ignore")

grid = {}
grid['classifier__max_depth'] = [15, 20, 25, 30]
grid['classifier__learning_rate'] = np.linspace(0.004, 0.3, num=5)
grid['classifier__reg_alpha'] = np.linspace(0.00000, 1, num=3)
grid['classifier__n_estimators'] = [300, 500, 2500]
grid['classifier__subsample'] = np.linspace(0.15, 1, num=5)


classifier = xgb.XGBClassifier(use_label_encoder=False, objective='binary:logistic')
pipeline = Pipeline([("scaler", MinMaxScaler()),
                    ("classifier", classifier)])



gscv = HalvingGridSearchCV(pipeline, 
                             grid, 
                             cv=3,
                             factor=2,
                             max_resources=40,
                             aggressive_elimination=True,
                             scoring='f1', 
                             n_jobs=4,
                          )


#l_grid_result = gscv.fit(X, y, classifier__eval_metric="auc")
l_best_params = {'classifier__learning_rate': 0.004, 'classifier__max_depth': 25, 'classifier__n_estimators': 2500, 'classifier__reg_alpha': 0.5, 'classifier__subsample': 1.0}
#l_best_params = l_grid_result.best_params_

eval_s = [(X, y), (X_test, y_test)]
print("Best parameters: {}".format(l_best_params))

# prepare the model with target scaling
best_depth = l_best_params['classifier__max_depth']
best_rate = l_best_params['classifier__learning_rate']
best_reg_alpha = l_best_params['classifier__reg_alpha']
best_n_estimators = l_best_params['classifier__n_estimators']
best_subsample = l_best_params['classifier__subsample']

classifier = xgb.XGBClassifier(max_depth=best_depth,
                                objective='binary:logistic',
                                            learning_rate=best_rate,
                                            reg_alpha=best_reg_alpha,
                                            subsample=best_subsample,
                                            n_estimators=best_n_estimators,
                              use_label_encoder=False,
                              silent=1,
                              verbosity=0)

classifier.fit(X, y, eval_set=eval_s, eval_metric="auc", verbose=False)
y_pred = classifier.predict(X_test)

fig, axs = plt.subplots(3, 1, figsize=(10, 15))

conMatrix = confusion_matrix(y_test, y_pred)

ax = sns.heatmap(conMatrix, annot=True, fmt=".0f", cmap='Blues', ax=axs[0])

ax.set_title('Seaborn Confusion Matrix\n')
ax.set_xlabel('Predicted Values')
ax.set_ylabel('Actual Values')

## Ticket labels - List must be in alphabetical order
ax.xaxis.set_ticklabels(['False','True'])
ax.yaxis.set_ticklabels(['False','True'])

fpr, tpr, _ = roc_curve(y_test, y_pred, drop_intermediate=False)
roc_display = RocCurveDisplay(fpr=fpr, tpr=tpr, roc_auc=auc(fpr, tpr))

prec, recall, _ = precision_recall_curve(y_test, y_pred)
pr_display = PrecisionRecallDisplay(precision=prec, recall=recall)

roc_display.plot(ax=axs[1])
pr_display.plot(ax=axs[2])

## Display the visualization of the Confusion Matrix.
plt.show()
# Out:
# Best parameters: {'classifier__learning_rate': 0.004, 'classifier__max_depth': 25, 'classifier__n_estimators': 2500, 'classifier__reg_alpha': 0.5, 'classifier__subsample': 1.0}

# %%
# Let's also print the accuracy and recall scores
print("Precision score: {:.2f}".format(metrics.precision_score(y_test, y_pred)))
print("Recall score: {:.2f}".format(metrics.recall_score(y_test, y_pred)))
print("Accuracy score: {:.2f}".format(metrics.accuracy_score(y_test, y_pred)))
print("F1 score: {:.2f}".format(metrics.f1_score(y_test, y_pred)))
# Out:
# Precision score: 0.43
# Recall score: 0.51
# Accuracy score: 0.96
# F1 score: 0.46

# %%
# Let's plot the learning curve for the XGB model:
# retrieve performance metrics
results = classifier.evals_result()
epochs = len(results['validation_0']['auc'])
x_axis = range(0, epochs)

# plot log loss
fig, ax = plt.subplots(figsize=(12,12))
ax.plot(x_axis, results['validation_0']['auc'], label='Train')
ax.plot(x_axis, results['validation_1']['auc'], label='Test')
ax.legend()

plt.ylabel('AUC')
plt.title('XGBoost AUC')
plt.show()

# %% [markdown]
# ## Extra Tree Tuning <a class="anchor" id="EXT"></a>

# %%
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.experimental import enable_halving_search_cv 
from sklearn.model_selection import HalvingGridSearchCV


import warnings
warnings.filterwarnings("ignore")

grid = {}
grid['classifier__max_depth'] = [12, 15, 20, 25]
grid['classifier__criterion'] = ["gini", "entropy"]
grid['classifier__n_estimators'] = [400, 500, 600]
grid['classifier__max_features'] = ["sqrt", "log2", len(X.columns)] 
grid['classifier__ccp_alpha'] = np.linspace(0.00000, 1, num=3)


classifier = ExtraTreesClassifier()
pipeline = Pipeline([("scaler", MinMaxScaler()),
                    ("classifier", classifier)])


gscv = HalvingGridSearchCV(pipeline, 
                             grid, 
                             cv=3,
                             factor=2,
                             max_resources=40,
                             aggressive_elimination=True,
                             scoring='f1', 
                             n_jobs=4
                          )

#gscv = GridSearchCV(
#                    pipeline, 
#                    grid, 
#                    scoring='f1', 
#                    cv=3,
#                    error_score=0.0,
#                    n_jobs=4)

l_grid_result = gscv.fit(X, y)
    
l_best_params = l_grid_result.best_params_

print("Best parameters: {}".format(l_best_params))

# prepare the model with target scaling

best_depth = l_best_params['classifier__max_depth']
best_n_estimators = l_best_params['classifier__n_estimators']
best_criterion = l_best_params['classifier__criterion']
best_max_features = l_best_params['classifier__max_features']
best_alpha = l_best_params['classifier__ccp_alpha']

classifier = ExtraTreesClassifier(max_depth=best_depth,
                                            criterion=best_criterion,
                                            ccp_alpha=best_alpha,
                                            max_features=best_max_features,
                                            n_estimators=best_n_estimators)

pipeline = Pipeline([("scaler", MinMaxScaler()),
                    ("classifier", classifier)])


pipeline.fit(X, y)
y_pred = pipeline.predict(X_test)

fig, axs = plt.subplots(3, 1, figsize=(10, 15))

conMatrix = confusion_matrix(y_test, y_pred)

ax = sns.heatmap(conMatrix, annot=True, fmt=".0f", cmap='Blues', ax=axs[0])

ax.set_title('Seaborn Confusion Matrix\n');
ax.set_xlabel('Predicted Values')
ax.set_ylabel('Actual Values');

## Ticket labels - List must be in alphabetical order
ax.xaxis.set_ticklabels(['False','True'])
ax.yaxis.set_ticklabels(['False','True'])

fpr, tpr, _ = roc_curve(y_test, y_pred, drop_intermediate=False)
roc_display = RocCurveDisplay(fpr=fpr, tpr=tpr, roc_auc=auc(fpr, tpr))

prec, recall, _ = precision_recall_curve(y_test, y_pred)
pr_display = PrecisionRecallDisplay(precision=prec, recall=recall)

roc_display.plot(ax=axs[1])
pr_display.plot(ax=axs[2])

## Display the visualization of the Confusion Matrix.
plt.show()
# Out:
# Best parameters: {'classifier__ccp_alpha': 0.0, 'classifier__criterion': 'entropy', 'classifier__max_depth': 12, 'classifier__max_features': 'log2', 'classifier__n_estimators': 500}

# %%
print("Precision score: {:.2f}".format(metrics.precision_score(y_test, y_pred)))
print("Recall score: {:.2f}".format(metrics.recall_score(y_test, y_pred)))
print("Accuracy score: {:.2f}".format(metrics.accuracy_score(y_test, y_pred)))
print("F1 score: {:.2f}".format(metrics.f1_score(y_test, y_pred)))
# Out:
# Precision score: 0.24
# Recall score: 0.84
# Accuracy score: 0.90
# F1 score: 0.38

# %% [markdown]
# ## Summary <a class="anchor" id="Summary"></a>
#
# Using the SMOTE oversampling really improved the scores on the linear LM classifiers, increasing the F1 scores for those across the board, so I used that for the tree based classifiers. The F1 score baseline was quite a bit better for these tree based ensembles, also. The best F1 score I got this time was from the random forest classifer, with an F1 of 0.46, but it was definitely all improved from last week.
#
# Since this dataset does not have an associated kaggle competition, I couldn't get a kaggle, although, I'd be curious at to what it would have been.
